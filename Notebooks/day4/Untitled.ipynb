# %%
@time using DataFrames
# Out:
#   6.309202 seconds (15.23 M allocations: 803.246 MiB, 5.47% gc time)

# %%
@time df=readtable("../day2/JuliaPlants.pedReformatted",separator=';');
# Out:
#   0.041520 seconds (407.55 k allocations: 10.655 MiB)

# %%
d=read.delim("../day2/JuliaPlants.pedReformatted",sep=';')

# %%
import pandas as pd
import time

# %%
k=pd.read_csv("../day2/JuliaPlants.pedReformatted",sep=";")
start = time.time()
k.head()
elapsed = time.time() - start
print(elapsed)
# Out:
# 0.0003650188446044922

# %%
system.time(head(d))
# Out:
#    user  system elapsed
#       0       0       0

# %%
@time first(df,6)
# Out:
#   0.000042 seconds (25 allocations: 1.797 KiB)
# 6×3 DataFrame
# │ Row │ ind    │ sire   │ dam    │
# │     │ Int64⍰ │ Int64⍰ │ Int64⍰ │
# ├─────┼────────┼────────┼────────┤
# │ 1   │ 11327  │ 353    │ 1183   │
# │ 2   │ 11328  │ 585    │ 1173   │
# │ 3   │ 11329  │ 600    │ 1174   │
# │ 4   │ 11330  │ 166    │ 1248   │
# │ 5   │ 11331  │ 23     │ 880    │
# │ 6   │ 11332  │ 459    │ 1104   │

# %%
@time names!(df,[:id,:father,:mother])
# Out:
#   0.663267 seconds (2.32 M allocations: 119.883 MiB, 7.86% gc time)
# 29500×3 DataFrame
# │ Row   │ id     │ father │ mother │
# │       │ Int64⍰ │ Int64⍰ │ Int64⍰ │
# ├───────┼────────┼────────┼────────┤
# │ 1     │ 11327  │ 353    │ 1183   │
# │ 2     │ 11328  │ 585    │ 1173   │
# │ 3     │ 11329  │ 600    │ 1174   │
# │ 4     │ 11330  │ 166    │ 1248   │
# │ 5     │ 11331  │ 23     │ 880    │
# │ 6     │ 11332  │ 459    │ 1104   │
# │ 7     │ 11333  │ 115    │ 699    │
# │ 8     │ 11334  │ 242    │ 714    │
# │ 9     │ 11335  │ 176    │ 902    │
# │ 10    │ 11336  │ 245    │ 696    │
# ⋮
# │ 29490 │ 30816  │ 28123  │ 28003  │
# │ 29491 │ 30817  │ 27100  │ 26991  │
# │ 29492 │ 30818  │ 28344  │ 27957  │
# │ 29493 │ 30819  │ 27154  │ 26742  │
# │ 29494 │ 30820  │ 27388  │ 28003  │
# │ 29495 │ 30821  │ 28098  │ 27806  │
# │ 29496 │ 30822  │ 26676  │ 28082  │
# │ 29497 │ 30823  │ 28082  │ 27583  │
# │ 29498 │ 30824  │ 28095  │ 27583  │
# │ 29499 │ 30825  │ 26584  │ 27834  │
# ...

# %%
J=[1 2 3
  4 5 6]
# Out:
# 2×3 Array{Int64,2}:
#  1  2  3
#  4  5  6

# %%
J'J
# Out:
# 3×3 Array{Int64,2}:
#  17  22  27
#  22  29  36
#  27  36  45

# %%
k=pd.read_csv("../")
